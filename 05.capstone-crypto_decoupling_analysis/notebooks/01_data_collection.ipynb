# %% [markdown]
# # Data Collection
#
# ## Objective
#
# The purpose of this notebook is to collect historical daily market data for Bitcoin (BTC), Ethereum (ETH), Gold (GLD), and the S&P 500 Index using the Yahoo Finance API.
#
# The collected datasets will serve as the primary data source for subsequent preprocessing, exploratory data analysis, statistical modeling, and financial analysis.
#
# This notebook also performs an initial assessment of data completeness before storing the datasets in the project's raw data directory.

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np

import yfinance as yf

from pathlib import Path

# %%
# Create project directories if they do not already exist

RAW_DATA_PATH = Path("crypto_project/data/raw")
RAW_DATA_PATH.mkdir(parents=True, exist_ok=True)

print("Raw data directory is ready.")
# Out:
# Raw data directory is ready.

# %%
assets = {
    "Bitcoin": "BTC-USD",
    "Ethereum": "ETH-USD",
    "Gold": "GLD",
    "SP500": "^GSPC"
}

# %%
#data downloading

market_data = {}

for asset_name, ticker in assets.items():

    print(f"Downloading {asset_name}...")

    df = yf.download(
        ticker,
        start="2019-01-01",
        end="2025-01-01",
        auto_adjust=True,
        progress=False
    )

    df.reset_index(inplace=True)

    market_data[asset_name] = df

print("Download Complete.")
# Out:
# ...
# Download Complete.

# %%
# Data Inspection

for asset_name, df in market_data.items():

    print("="*60)
    print(asset_name)

    display(df.head())

    print(df.info())
# Out:
# ...
# Bitcoin
# Price        Date        Close         High          Low         Open  \
# Ticker                 BTC-USD      BTC-USD      BTC-USD      BTC-USD
# 0      2019-01-01  3843.520020  3850.913818  3707.231201  3746.713379
# 1      2019-01-02  3943.409424  3947.981201  3817.409424  3849.216309
# 2      2019-01-03  3836.741211  3935.685059  3826.222900  3931.048584
# 3      2019-01-04  3857.717529  3865.934570  3783.853760  3832.040039
# 4      2019-01-05  3845.194580  3904.903076  3836.900146  3851.973877
#
# Price       Volume
# Ticker     BTC-USD
# 0       4324200990
# 1       5244856836
# 2       4530215219
# 3       4847965467
# 4       5137609824
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2192 entries, 0 to 2191
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Date, )           2192 non-null   datetime64[ns]
#  1   (Close, BTC-USD)   2192 non-null   float64
# ...

# %%
# Data Quality Assessment

summary = []

for asset_name, df in market_data.items():

    summary.append({

        "Asset": asset_name,

        "Rows": len(df),

        "Columns": df.shape[1],

        "Missing Values": df.isna().sum().sum(),

        "Start Date": df["Date"].min(),

        "End Date": df["Date"].max()

    })

summary_df = pd.DataFrame(summary)

summary_df
# Out:
#       Asset  Rows  Columns  Missing Values Start Date   End Date
# 0   Bitcoin  2192        6               0 2019-01-01 2024-12-31
# 1  Ethereum  2192        6               0 2019-01-01 2024-12-31
# 2      Gold  1510        6               0 2019-01-02 2024-12-31
# 3     SP500  1510        6               0 2019-01-02 2024-12-31

# %%
# Saving raw data

for asset_name, df in market_data.items():
     # Flatten MultiIndex columns if present
    if isinstance(df.columns, pd.MultiIndex):
        df.columns = df.columns.get_level_values(0)

    filename = asset_name.lower() + ".csv"
    df.to_csv(RAW_DATA_PATH / filename, index=False)

print("All raw datasets saved successfully.")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[40], line 9
#       6         df.columns = df.columns.get_level_values(0)
#       8     filename = asset_name.lower() + ".csv"
# ----> 9     df.to_csv(RAW_DATA_PATH / filename, index=False)
#      11 print("All raw datasets saved successfully.")
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# # Summary
#
# The historical market data for Bitcoin, Ethereum, Gold, and the S&P 500 were successfully collected using the Yahoo Finance API.
#
# The datasets were inspected for completeness and exported to the project's raw data directory. These files will be used in the next notebook for data cleaning and preprocessing.
#
# ### Next Step
#
# Notebook 02 — Data Cleaning & Preprocessing
